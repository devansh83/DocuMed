# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
project=pd.read_csv(r"C:\Users\tanus\Downloads\Summer Project  Preferences '24 (Responses) - Form responses 1.csv")

# %%
project
# Out:
#                 Timestamp                Name Roll Number  \
# 0     02/04/2024 16:50:35        Aryan Kadam       230221
# 1     02/04/2024 16:50:46  Narayan A. Somaiya      231019
# 2     02/04/2024 16:53:24    Shantanu Prakash       23952
# 3     02/04/2024 16:54:29      Divyansh Singh      230384
# 4     02/04/2024 16:57:56        Om Chaudhari      230715
# ...                   ...                 ...         ...
# 999   04/04/2024 13:19:16         Sunny kumar      231052
# 1000  04/04/2024 13:21:22         VIKAS MEENA      231150
# 1001  04/04/2024 15:52:11       Palak Agarwal      230726
# 1002  04/04/2024 17:20:58          Avula Ajay      230248
# 1003  04/04/2024 18:53:41   vattikuti susruth      231128
#
#                 IITK Email ID                        Gmail ID Contact Number  \
# 0     aryankadam23@iitk.ac.in        aryankadam2055@gmail.com     7499314138
# 1      snarayana23@iitk.ac.in    narayansomaiya2004@gmail.com     9427960210
# ...

# %%
project.drop('Timestamp', axis=1, inplace=True)

# %%
project.drop('Past Experience', axis=1, inplace=True)

# %%
project.drop('Gmail ID', axis=1, inplace=True)

# %%
project
# Out:
#                     Name Roll Number            IITK Email ID Contact Number  \
# 0           Aryan Kadam       230221  aryankadam23@iitk.ac.in     7499314138
# 1     Narayan A. Somaiya      231019   snarayana23@iitk.ac.in     9427960210
# 2       Shantanu Prakash       23952   shantanup23@iitk.ac.in     9334335359
# 3         Divyansh Singh      230384   sdivyansh23@iitk.ac.in     9305388225
# 4           Om Chaudhari      230715        omcc23@iitk.ac.in     9699776686
# ...                  ...         ...                      ...            ...
# 999          Sunny kumar      231052      sunnyk23@iitk.ac.in     7903302971
# 1000         VIKAS MEENA      231150  vikasmeena23@iitk.ac.in     9079635893
# 1001       Palak Agarwal      230726      palaka23@iitk.ac.in     8090216122
# 1002          Avula Ajay      230248       ajayl23@iitk.ac.in     9701013213
# 1003   vattikuti susruth      231128    vsusruth23@iitk.ac.in     9391478386
#
# ...

# %%
row=[]
for i in range(len(project)):
    if(project.iloc[i][4]=='FAC - QuantWeb' or project.iloc[i][4]=='FAC - AlgoRisk Insights' or project.iloc[i][4]=='FAC - Quant Forecast' or project.iloc[i][4]=='FAC - Defi-Unchained' or project.iloc[i][4]=='FAC - Market Insights' or project.iloc[i][4]=='FAC - Deciphering Decisions' or project.iloc[i][4]=='FAC - AlgoRhythmic X: Fundamentals of Quant Finance' or project.iloc[i][4]=='FAC - Intelli Invest'):
        row.append(project.iloc[i])
    elif(project.iloc[i][5]=='FAC - QuantWeb' or project.iloc[i][5]=='FAC - AlgoRisk Insights' or project.iloc[i][5]=='FAC - Quant Forecast' or project.iloc[i][5]=='FAC - Defi-Unchained' or project.iloc[i][5]=='FAC - Market Insights' or project.iloc[i][5]=='FAC - Deciphering Decisions' or project.iloc[i][5]=='FAC - AlgoRhythmic X: Fundamentals of Quant Finance' or project.iloc[i][5]=='FAC - Intelli Invest'):
        row.append(project.iloc[i])
    elif(project.iloc[i][6]=='FAC - QuantWeb' or project.iloc[i][6]=='FAC - AlgoRisk Insights' or project.iloc[i][6]=='FAC - Quant Forecast' or project.iloc[i][6]=='FAC - Defi-Unchained' or project.iloc[i][6]=='FAC - Market Insights' or project.iloc[i][6]=='FAC - Deciphering Decisions' or project.iloc[i][6]=='FAC - AlgoRhythmic X: Fundamentals of Quant Finance' or project.iloc[i][6]=='FAC - Intelli Invest'):
        row.append(project.iloc[i])
    elif(project.iloc[i][7]=='FAC - QuantWeb' or project.iloc[i][7]=='FAC - AlgoRisk Insights' or project.iloc[i][7]=='FAC - Quant Forecast' or project.iloc[i][7]=='FAC - Defi-Unchained' or project.iloc[i][7]=='FAC - Market Insights' or project.iloc[i][7]=='FAC - Deciphering Decisions' or project.iloc[i][7]=='FAC - AlgoRhythmic X: Fundamentals of Quant Finance' or project.iloc[i][7]=='FAC - Intelli Invest'):
        row.append(project.iloc[i])

# %%
hello.append(project.iloc[0])

# %%
hello=[]

# %%
hello
# Out:
# [Name                          Aryan Kadam
#  Roll Number                         230221
#  IITK Email ID      aryankadam23@iitk.ac.in
#  Contact Number                  7499314138
#  Preference 1          PClub - AlgoArena2.o
#  Preference 2      PClub - IITK Mail Client
#  Preference 3      PClub - Capture The Flag
#  Preference 4      PClub - Mastering Web3.0
#  Name: 0, dtype: object]

# %%
row
# Out:
# [Name                     Shantanu Prakash
#  Roll Number                         23952
#  IITK Email ID      shantanup23@iitk.ac.in
#  Contact Number                 9334335359
#  Preference 1               FAC - QuantWeb
#  Preference 2      FAC - AlgoRisk Insights
#  Preference 3         FAC - Quant Forecast
#  Preference 4         FAC - Defi-Unchained
#  Name: 2, dtype: object,
#  Name                            Nipam Ghorai
#  Roll Number                           230703
#  IITK Email ID            nipamg23@iitk.ac.in
#  Contact Number                    9547936229
#  Preference 1      BCS - LLuminating language
#  Preference 2                BCS - Style Swap
#  Preference 3              BCS - Sound Refine
#  Preference 4            FAC - Intelli Invest
#  Name: 5, dtype: object,
#  Name                                                 Aaryan Chandra
#  Roll Number                                                  230021
# ...

# %%
row.to_csv(r"C:\Users\tanus\Downloads\Final.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 row.to_csv(r"C:\Users\tanus\Downloads\Final.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
final=pd.DataFrame(row)

# %%
final
# Out:
#                   Name Roll Number            IITK Email ID Contact Number  \
# 2     Shantanu Prakash       23952   shantanup23@iitk.ac.in     9334335359
# 5         Nipam Ghorai      230703      nipamg23@iitk.ac.in     9547936229
# 15      Aaryan Chandra      230021     aaryanc23@iitk.ac.in     9315210739
# 18     Gaurav Tripathi      230414     gauravt23@iitk.ac.in     7880924353
# 23        Sanjay Khara      230914     sanjayk23@iitk.ac.in     8780724277
# ...                ...         ...                      ...            ...
# 995     Tushar Chaube       231100    tusharan23@iitk.ac.in     9404696546
# 996    Ashish Upadhyay      230231     ashishu23@iitk.ac.in     9520159580
# 998    Divi Pothukuchi      230378       divip23@iitk.ac.in     9884097619
# 999        Sunny kumar      231052      sunnyk23@iitk.ac.in     7903302971
# 1000       VIKAS MEENA      231150  vikasmeena23@iitk.ac.in     9079635893
#
#                                            Preference 1  \
# ...

# %%
final.to_csv(r"C:\Users\tanus\Downloads\FAC summer project responses.csv")

# %%
final
# Out:
#                   Name Roll Number            IITK Email ID Contact Number  \
# 2     Shantanu Prakash       23952   shantanup23@iitk.ac.in     9334335359
# 5         Nipam Ghorai      230703      nipamg23@iitk.ac.in     9547936229
# 15      Aaryan Chandra      230021     aaryanc23@iitk.ac.in     9315210739
# 18     Gaurav Tripathi      230414     gauravt23@iitk.ac.in     7880924353
# 23        Sanjay Khara      230914     sanjayk23@iitk.ac.in     8780724277
# ...                ...         ...                      ...            ...
# 995     Tushar Chaube       231100    tusharan23@iitk.ac.in     9404696546
# 996    Ashish Upadhyay      230231     ashishu23@iitk.ac.in     9520159580
# 998    Divi Pothukuchi      230378       divip23@iitk.ac.in     9884097619
# 999        Sunny kumar      231052      sunnyk23@iitk.ac.in     7903302971
# 1000       VIKAS MEENA      231150  vikasmeena23@iitk.ac.in     9079635893
#
#                                            Preference 1  \
# ...

# %%
lecture=[]
for i in range(100):
    lecture.append('L10')
    lecture.append('L11')
    lecture.append('L12')
    lecture.append('L14')
    lecture.append('L18')
x=len(final)-500
for i in range(x):
    lecture.append('L18')
    
final['Lecture Hall']=lecture

# %%
final
# Out:
#                   Name Roll Number            IITK Email ID Contact Number  \
# 2     Shantanu Prakash       23952   shantanup23@iitk.ac.in     9334335359
# 5         Nipam Ghorai      230703      nipamg23@iitk.ac.in     9547936229
# 15      Aaryan Chandra      230021     aaryanc23@iitk.ac.in     9315210739
# 18     Gaurav Tripathi      230414     gauravt23@iitk.ac.in     7880924353
# 23        Sanjay Khara      230914     sanjayk23@iitk.ac.in     8780724277
# ...                ...         ...                      ...            ...
# 995     Tushar Chaube       231100    tusharan23@iitk.ac.in     9404696546
# 996    Ashish Upadhyay      230231     ashishu23@iitk.ac.in     9520159580
# 998    Divi Pothukuchi      230378       divip23@iitk.ac.in     9884097619
# 999        Sunny kumar      231052      sunnyk23@iitk.ac.in     7903302971
# 1000       VIKAS MEENA      231150  vikasmeena23@iitk.ac.in     9079635893
#
#                                            Preference 1  \
# ...
